# %%
# 딥러닝을 구동하는 데 필요한 케라스 함수를 불러옵니다.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import hvplot.pandas
import os
# %matplotlib inline
np.random.seed(3)
data = pd.read_csv('../dataset/Ecommerce Customers.csv')

# %%
data.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
data.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
# %matplotlib inline
sns.set_palette('GnBu_r')
sns.jointplot(x='Time on Website',y='Yearly Amount Spent',data=data)
plt.show()

# %%
sns.jointplot(x='Time on App',y='Yearly Amount Spent',data=data)
plt.show()

# %%
sns.jointplot(x='Avg. Session Length',y='Yearly Amount Spent',data=data)
plt.show()

# %%
sns.jointplot(x='Avatar',y='Yearly Amount Spent',data=data)
plt.show()

# %%
sns.jointplot(x='Length of Membership',y='Yearly Amount Spent',data=data)
plt.show()

# %%
import pandas_profiling as pp
pp.ProfileReport(data)
#Time on website가 영향력이 없어보이네
#Year amount spent를 예상하는데 있어서 Length of membership, Time on app, Session length 가 많은 상관관계를 가짐
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-12-08 10:39:49.824281&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
data.describe()
# Time on website가 어느 정도의 수치를 나타내는지 확인하여 왜 영향력이 약한지 확인
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
data.info()
# float64타입이므로 밑에 셀의 2,3 번째 라인에서 형변환 해줬음
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
np.random.seed(3)

dataset = data.values
X = dataset[:,3:7].astype(float)
Y = dataset[:,7].astype(float)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
np.random.seed(3)

data = pd.read_csv('../dataset/Ecommerce Customers.csv', usecols = ["Avg. Session Length",
            "Time on App", "Time on Website", "Length of Membership", "Yearly Amount Spent"])
dataset = data.values
X = dataset[:,0:4].astype(float)
Y = dataset[:,4].astype(float)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
np.random.seed(3)

data = pd.read_csv('../dataset/Ecommerce Customers.csv', usecols = ["Avg. Session Length",
            "Time on App", "Length of Membership", "Yearly Amount Spent"])
dataset = data.values
X = dataset[:,0:3].astype(float)
Y = dataset[:,3].astype(float)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# from sklearn.linear_model import Ridge
# fit = Ridge(fit_intercept=True, normalize=True, random_state=123).fit(X_train, Y_train)

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(X_train, Y_train)
print(ridge.score(X_train, Y_train))
print(ridge.score(X_test, Y_test))

i = 0;
result = 0;
Y_prediction = ridge.predict(X_test)
for i in range(10):
    label = Y_test[i]
    prediction = Y_prediction[i]
    result += abs(prediction-label)
    i += 1
    print("실제가격: {:.3f}, 예상가격: {:.3f}".format(label, prediction))
result = result/i
print(f"오차 : {result:.2f}" )
# Out:
# 0.9834715550528731
# 0.9853331728778434
# 실제가격: 552.940, 예상가격: 534.296
# 실제가격: 378.474, 예상가격: 373.137
# 실제가격: 490.739, 예상가격: 487.048
# 실제가격: 538.775, 예상가격: 543.906
# 실제가격: 476.767, 예상가격: 464.193
# 실제가격: 663.804, 예상가격: 647.806
# 실제가격: 473.360, 예상가격: 479.021
# 실제가격: 486.839, 예상가격: 484.910
# 실제가격: 548.519, 예상가격: 555.507
# 실제가격: 462.657, 예상가격: 458.372
# 오차 : 8.02

# %%
# 중요
from sklearn.linear_model import Ridge

train_score = []
test_score = []
alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]
for alpha in alpha_list:
    ridge = Ridge(alpha=alpha)
    ridge.fit(X_train, Y_train)
    train_score.append(ridge.score(X_train, Y_train))
    test_score.append(ridge.score(X_test, Y_test))
print(train_score)
print(test_score)
i = 0;
result = 0;
Y_prediction = ridge.predict(X_test)
for i in range(10):
    label = Y_test[i]
    prediction = Y_prediction[i]
    result += abs(prediction-label)
    i += 1
    print("실제가격: {:.3f}, 예상가격: {:.3f}".format(label, prediction))
result = result/i
print(f"오차 : {result:.2f}" )
# Out:
# [0.9834796253018022, 0.9834796244982926, 0.9834795441892823, 0.9834715550528731, 0.9827126856282745, 0.9345113195510543]
# [0.985353793635271, 0.9853536818329427, 0.9853524894546684, 0.9853331728778434, 0.9844416533732027, 0.9338464375164013]
# 실제가격: 552.940, 예상가격: 527.449
# 실제가격: 378.474, 예상가격: 401.848
# 실제가격: 490.739, 예상가격: 490.698
# 실제가격: 538.775, 예상가격: 534.612
# 실제가격: 476.767, 예상가격: 472.847
# 실제가격: 663.804, 예상가격: 615.572
# 실제가격: 473.360, 예상가격: 484.090
# 실제가격: 486.839, 예상가격: 489.338
# 실제가격: 548.519, 예상가격: 544.022
# 실제가격: 462.657, 예상가격: 468.481
# 오차 : 12.88

# %%
import matplotlib.pyplot as plt
plt.plot(np.log10(alpha_list), train_score, 'r')
plt.plot(np.log10(alpha_list), test_score)
plt.show()

# %%
model = Sequential()
model.add(Dense(30, input_dim=3, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1))

model.compile(loss='mean_squared_error',
              optimizer='adam')

model.fit(X_train, Y_train, epochs=200, batch_size=10)

i = 0;
result = 0;
# 예측 값과 실제 값의 비교
Y_prediction = model.predict(X_test).flatten()
for i in range(10):
    label = Y_test[i]
    prediction = Y_prediction[i]
    result += abs(prediction-label)
    i += 1
    print("실제가격: {:.3f}, 예상가격: {:.3f}".format(label, prediction))
result = result/i
print(f"오차 : {result:.2f}" )
# Out:
# Train on 350 samples
# Epoch 1/200
# 350/350 [==============================] - 0s 624us/sample - loss: 259505.8402
# Epoch 2/200
# 350/350 [==============================] - 0s 75us/sample - loss: 258309.1107
# Epoch 3/200
# 350/350 [==============================] - 0s 74us/sample - loss: 255612.5415
# Epoch 4/200
# 350/350 [==============================] - 0s 77us/sample - loss: 250223.9277
# Epoch 5/200
# 350/350 [==============================] - 0s 85us/sample - loss: 240930.6616
# Epoch 6/200
# 350/350 [==============================] - 0s 83us/sample - loss: 226534.8210
# Epoch 7/200
# 350/350 [==============================] - 0s 77us/sample - loss: 206132.6714
# Epoch 8/200
# 350/350 [==============================] - 0s 71us/sample - loss: 170883.3471
# Epoch 9/200
# 350/350 [==============================] - 0s 76us/sample - loss: 108901.7433
# Epoch 10/200
# 350/350 [==============================] - 0s 85us/sample - loss: 54847.6933
# Epoch 11/200
# ...

# %%
model = Sequential()
model.add(Dense(30, input_dim=3, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1))

model.compile(loss='mean_squared_error',
              optimizer='adam')

model.fit(X_train, Y_train, epochs=200, batch_size=10)

i = 0;
result = 0;
# 예측 값과 실제 값의 비교
Y_prediction = model.predict(X_test).flatten()
for i in range(10):
    label = Y_test[i]
    prediction = Y_prediction[i]
    result += abs(prediction-label)
    i += 1
    print("실제가격: {:.3f}, 예상가격: {:.3f}".format(label, prediction))
result = result/i
print(f"오차 : {result:.2f}" )
# Out:
# Train on 350 samples
# Epoch 1/200
# 350/350 [==============================] - 0s 604us/sample - loss: 255701.4598
# Epoch 2/200
# 350/350 [==============================] - 0s 83us/sample - loss: 248628.4562
# Epoch 3/200
# 350/350 [==============================] - 0s 85us/sample - loss: 241724.6170
# Epoch 4/200
# 350/350 [==============================] - 0s 77us/sample - loss: 232347.2420
# Epoch 5/200
# 350/350 [==============================] - 0s 77us/sample - loss: 219612.5089
# Epoch 6/200
# 350/350 [==============================] - 0s 80us/sample - loss: 202368.0304
# Epoch 7/200
# 350/350 [==============================] - 0s 123us/sample - loss: 179920.7406
# Epoch 8/200
# 350/350 [==============================] - 0s 85us/sample - loss: 152648.2804
# Epoch 9/200
# 350/350 [==============================] - 0s 82us/sample - loss: 122120.9563
# Epoch 10/200
# 350/350 [==============================] - 0s 78us/sample - loss: 90932.1547
# Epoch 11/200
# ...

# %%
model = Sequential()
model.add(Dense(30, input_dim=3, activation='relu'))
model.add(Dense(1))

model.compile(loss='mean_squared_error',
              optimizer='adam')

model.fit(X_train, Y_train, epochs=200, batch_size=10)

i = 0;
result = 0;
# 예측 값과 실제 값의 비교
Y_prediction = model.predict(X_test).flatten()
for i in range(10):
    label = Y_test[i]
    prediction = Y_prediction[i]
    result += abs(prediction-label)
    i += 1
    print("실제가격: {:.3f}, 예상가격: {:.3f}".format(label, prediction))
result = result/i
print(f"오차 : {result:.2f}" )
# Out:
# Train on 350 samples
# Epoch 1/200
# 350/350 [==============================] - 0s 521us/sample - loss: 260513.7281
# Epoch 2/200
# 350/350 [==============================] - 0s 71us/sample - loss: 250384.4897
# Epoch 3/200
# 350/350 [==============================] - 0s 71us/sample - loss: 239858.1799
# Epoch 4/200
# 350/350 [==============================] - 0s 68us/sample - loss: 228672.1888
# Epoch 5/200
# 350/350 [==============================] - 0s 71us/sample - loss: 216407.0920
# Epoch 6/200
# 350/350 [==============================] - 0s 71us/sample - loss: 202859.1594
# Epoch 7/200
# 350/350 [==============================] - 0s 74us/sample - loss: 188022.1420
# Epoch 8/200
# 350/350 [==============================] - 0s 71us/sample - loss: 172188.4138
# Epoch 9/200
# 350/350 [==============================] - 0s 73us/sample - loss: 155769.9913
# Epoch 10/200
# 350/350 [==============================] - 0s 72us/sample - loss: 139104.7377
# Epoch 11/200
# ...

# %%
model = Sequential()
model.add(Dense(30, input_dim=4, activation='softplus'))
model.add(Dense(1))

model.compile(loss='mean_squared_error',
              optimizer='adam')

model.fit(X_train, Y_train, epochs=200, batch_size=10, verbose = 0)

i = 0;
result = 0;
# 예측 값과 실제 값의 비교
Y_prediction = model.predict(X_test).flatten()
for i in range(10):
    label = Y_test[i]
    prediction = Y_prediction[i]
    result += abs(prediction-label)
    i += 1
    print("실제가격: {:.3f}, 예상가격: {:.3f}".format(label, prediction))
result = result/i
print(f"오차 : {result:.2f}" )
# Out:
# 실제가격: 552.940, 예상가격: 524.489
# 실제가격: 378.474, 예상가격: 394.144
# 실제가격: 490.739, 예상가격: 494.550
# 실제가격: 538.775, 예상가격: 568.480
# 실제가격: 476.767, 예상가격: 478.932
# 실제가격: 663.804, 예상가격: 640.939
# 실제가격: 473.360, 예상가격: 502.538
# 실제가격: 486.839, 예상가격: 482.405
# 실제가격: 548.519, 예상가격: 540.408
# 실제가격: 462.657, 예상가격: 457.529
# 오차 : 14.95

# %%
model = Sequential()
model.add(Dense(30, input_dim=4, activation='elu'))
model.add(Dense(1))

model.compile(loss='mean_squared_error',
              optimizer='adam')

model.fit(X_train, Y_train, epochs=200, batch_size=10, verbose = 0)

i = 0;
result = 0;
# 예측 값과 실제 값의 비교
Y_prediction = model.predict(X_test).flatten()
for i in range(10):
    label = Y_test[i]
    prediction = Y_prediction[i]
    result += abs(prediction-label)
    i += 1
    print("실제가격: {:.3f}, 예상가격: {:.3f}".format(label, prediction))
result = result/i
print(f"오차 : {result:.2f}" )
# Out:
# 실제가격: 552.940, 예상가격: 525.737
# 실제가격: 378.474, 예상가격: 398.335
# 실제가격: 490.739, 예상가격: 496.781
# 실제가격: 538.775, 예상가격: 577.746
# 실제가격: 476.767, 예상가격: 482.364
# 실제가격: 663.804, 예상가격: 642.971
# 실제가격: 473.360, 예상가격: 509.061
# 실제가격: 486.839, 예상가격: 485.351
# 실제가격: 548.519, 예상가격: 537.361
# 실제가격: 462.657, 예상가격: 458.270
# 오차 : 17.12

# %%
model = Sequential()
model.add(Dense(30, input_dim=3, activation='sigmoid'))
model.add(Dense(1))

model.compile(loss='mean_squared_error',
              optimizer='adam')

model.fit(X_train, Y_train, epochs=200, batch_size=10)

i = 0;
result = 0;
# 예측 값과 실제 값의 비교
Y_prediction = model.predict(X_test).flatten()
for i in range(10):
    label = Y_test[i]
    prediction = Y_prediction[i]
    result += abs(prediction-label)
    i += 1
    print("실제가격: {:.3f}, 예상가격: {:.3f}".format(label, prediction))
result = result/i
print(f"오차 : {result:.2f}" )
# Out:
# Train on 350 samples
# Epoch 1/200
# 350/350 [==============================] - 0s 1ms/sample - loss: 258571.6719
# Epoch 2/200
# 350/350 [==============================] - 0s 70us/sample - loss: 257388.3290
# Epoch 3/200
# 350/350 [==============================] - 0s 75us/sample - loss: 256382.8170
# Epoch 4/200
# 350/350 [==============================] - 0s 71us/sample - loss: 255141.9701
# Epoch 5/200
# 350/350 [==============================] - 0s 71us/sample - loss: 253407.9442
# Epoch 6/200
# 350/350 [==============================] - 0s 70us/sample - loss: 251726.9375
# Epoch 7/200
# 350/350 [==============================] - 0s 74us/sample - loss: 250615.3571
# Epoch 8/200
# 350/350 [==============================] - 0s 68us/sample - loss: 249692.3473
# Epoch 9/200
# 350/350 [==============================] - 0s 68us/sample - loss: 248824.4987
# Epoch 10/200
# 350/350 [==============================] - 0s 70us/sample - loss: 247988.0433
# Epoch 11/200
# ...
